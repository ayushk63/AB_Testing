# %%
import pandas as pd
import numpy as np
from scipy.stats import ttest_rel

# %%
df = pd.read_csv("Customer Satisfaction Scores and Behavior Data.csv")
df.head()
# Out:
#    Customer_ID Group  Satisfaction_Score  Age  Gender        Location  \
# 0  81-237-4704     A                   6   55    Male      Phoenix.AZ
# 1  14-117-0504     A                   7   46  Female  Los Angeles.CA
# 2  21-336-6416     A                   7   55  Female      Houston.TX
# 3  59-781-3650     A                   1   42    Male  Los Angeles.CA
# 4  52-712-5734     B                   9   37    Male       Austin.TX
#
#   Purchase_History Support_Contacted Loyalty_Level Satisfaction_Factor
# 0              Yes                No           Low               Price
# 1              Yes                No           Low     Product Variety
# 2              Yes               Yes           Low           Packaging
# 3              Yes                No        Medium               Price
# 4              Yes               Yes        Medium           Packaging

# %%
data = df[["Satisfaction_Score", "Support_Contacted"]]
data.head()
# Out:
#    Satisfaction_Score Support_Contacted
# 0                   6                No
# 1                   7                No
# 2                   7               Yes
# 3                   1                No
# 4                   9               Yes

# %%
t_stat, p_value = ttest_rel(sample_before, sample_after)

print("t statistic: ", t_stat)
print("p value: ", p_value)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 t_stat, p_value = ttest_rel(sample_before, sample_after)
#       3 print("t statistic: ", t_stat)
#       4 print("p value: ", p_value)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\scipy\stats\_axis_nan_policy.py:528, in _axis_nan_policy_factory.<locals>.axis_nan_policy_decorator.<locals>.axis_nan_policy_wrapper(***failed resolving arguments***)
#     525     samples = [np.asarray(sample.ravel()) for sample in samples]
#     526 else:
#     527     # don't ignore any axes when broadcasting if paired
# --> 528     samples = _broadcast_arrays(samples, axis=axis if not paired else None)
#     529     axis = np.atleast_1d(axis)
#     530     n_axes = len(axis)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\scipy\stats\_axis_nan_policy.py:51, in _broadcast_arrays(arrays, axis, xp)
# ...

# %%
sample_before = np.array(data['Satisfaction_Score'][data['Support_Contacted'] == 'No'])
sample_after = np.array(data['Satisfaction_Score'][data['Support_Contacted'] == 'Yes'])

# %%
alpha = 0.05

if p_value < alpha:
    print("Null Hypothesis Rejected")
    print("There is a significant difference between satisfaction scores before and after contacting support")
else:
    print("Failed to Reject Null Hypothesis")
    print("There is no significant difference between satisfaction scores before and after contacting support")
